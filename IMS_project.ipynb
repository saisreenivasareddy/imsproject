# %%
import json
import time                              # importing libraries
fd = open('sales.json','w')
sd = open('stock.json','w')             #opening files
avaliable_code = [600001,600002,600003]  #coopen codes available
price =0
mrp = 0
x = []
s = 0
kart = []
kartage = []
again = [0]
temp = 0                                  #creating and initaling temparary variables
def dmrp():                               # mrp calculating function defination for COOPENS
  sum = 0
  for i in x:
    sum += int(i)
  sum = sum * 0.75
  if sum > 5000:
    sum = sum*0.60
    print("your bill is ",sum)
  else:
    print("your bill is ",sum)
def mrp():                                #mrp calculating function defination for normal offers
  sum = 0
  for i in x:
    sum += int(i)
  if sum > 5000:
    sum = sum*0.60
    print("your bill is ",sum)
  else:
    print("your bill is ",sum)
print("Hello User !  Welcome to our mart ")                           # first  user display
home = int(input("To SHOP  press 1  or   to see OFFERS press 2   : ")) # asking user to buy products or offers and not letting them  to go back for marketing purpose
if home == 1:
    pass
else:
    print(" Hello User   \n our MART will provide almost all homeneed appliances with UNLIMITED stock !!!!! TODAYS OFFERS are shop more than 5000 get 50% OFF   happpy shopping   ")
def billing():                                                 # billing function defination (filtering user WITH and WITHOUT coopens)
  coopuns = int(input("please enter your coopun code"))
  for num in avaliable_code:
    if num == coopuns:
      print("yes u r eligible for discount")
      dmrp()
      break
    else:
      print("searching")
      continue
      print("not eligible")
name = input("Hello User  please enter your name  : ")         # asking user to enter name

#creating product dictorines

choco      = { "no : ":1001,"brand name:":"American Chocolate","Mrp:":"450 rupees","discount : ":"50 rupees","new price :":400,"qn :":1}
nodeels      = { "no : ":1002,"brand name :":"Atta nooddels spicy onion ","Mrp:":"300 rupees","discount : ":"50 rupees","new price :":250,"qn :":0}
idlyrava = { "no : ":1003,"brand name :":"Ashirvad ","Mrp:":"750 rupees","discount : ":"50 rupees","new price :":700,"qn :":0}
dosarava = { "no : ":1004,"brand name :":"Ashurvad","Mrp:":"450 rupees","discount : ":"20 rupees","new price :":430,"qn :":9}
chairs= { "no : ":2001,"brand name :":"supercell ","Mrp:":"3450 rupees","discount : ":"50 rupees","new price :":3400,"qn :":9}
studychair= { "no : ":2002,"brand name :":"Study well ","Mrp:":"650 rupees","discount : ":"50 rupees","new price :":600,"qn :":9}
diningtable= { "no : ":2003,"brand name :":"eat wall ","Mrp:":"2450 rupees","discount : ":"50 rupees","new price :":2400,"qn :":9}
decorators= { "no : ":2004," brand name :":"Happy home decorators ","Mrp:":"9450 rupees","discount : ":"50 rupees","new price :":9400,"qn :":9}
luggage_bag = { "no : ":2004," brand name :":"Happy home decorators ","Mrp:":"3550 rupees","discount : ":"50 rupees","new price :":3500,"qn :":9}
samsung_tv= { "no : ":3001," brand name :":"samsung tv ","Mrp:":"44550 rupees","discount : ":"500 rupees","new price :":44050,"qn :":9}
realme_tv= { "no : ":3002," brand name :":"realme tv ","Mrp:":"39500 rupees","discount : ":"500 rupees","new price :":39000,"qn :":9}
mi_tv= { "no : ":3003," brand name :":"mi tv ","Mrp:":"46500 rupees","discount : ":"500 rupees","new price :":46000,"qn :":9}
dell_laptop= { "no : ":4001," brand name :":"dell laptop ","Mrp:":"75000 rupees","discount : ":"5000  rupees","new price :":70000,"qn :":9}
hp_laptop= { "no : ":4002," brand name :":"Hp laptop ","Mrp:":"69500 rupees","discount : ":"500 rupees","new price :":69000,"qn :":9}
mi_laptop= { "no : ":4003," brand name :":"mi laptop ","Mrp:":"55500 rupees","discount : ":"500 rupees","new price :":55000,"qn :":9}
samsung_moblie= { "no : ":5001," brand name :":"Samsung mobile s10 ","Mrp:":"21000 rupees","discount : ":"00 rupees","new price :":21000,"qn :":9}
mi_mobile= { "no : ":5002," brand name :":"mi 6a moblies","Mrp:":"16500 rupees","discount : ":"500 rupees","new price :":16000,"qn :":9}
realme_mobile= { "no : ":5003," brand name :":"realme 3 pro ","Mrp:":"1450 rupees","discount : ":"50 rupees","new price :":14000,"qn :":9}
oppo_mobile= { "no : ":5004," brand name :":"oppo 3 pro ","Mrp:":"11450 rupees","discount : ":"450 rupees","new price :":11000,"qn :":9}
bosch_wm= { "no : ":6001," brand name :":"WASHING MACHINE ","Mrp:":"19950 rupees","discount : ":"50 rupees","new price :":19900,"qn :":9}
samsung_wm= { "no : ":6002," brand name :":"SAMSUNG WASHING MACHINE ","Mrp:":"20500 rupees","discount : ":"500 rupees","new price :":20000,"qn :":9}
samsung_fg= { "no : ":7001," brand name :":"SAMSUNG FRIDGE","Mrp:":"44500 rupees","discount : ":"500 rupees","new price :":44000,"qn :":9}
bosch_fg= { "no : ":7002," brand name :":"BOSCH FRIDGE ","Mrp:":"41500 rupees","discount : ":"500 rupees","new price :":41000,"qn :":9}
sunshine_home= { "no : ":8001," brand name :":"LAMPS ","Mrp:":"950 rupees","discount : ":"50 rupees","new price :":900,"qn :":9}
moonlight_home= { "no : ":8002," brand name :":"MOON LAMPS ","Mrp:":"850 rupees","discount : ":"50 rupees","new price :":800,"qn :":9}
plesent_stars= { "no : ":8003," brand name :":"STAR LAMPS ","Mrp:":"1150 rupees","discount : ":"50 rupees","new price :":1100,"qn :":9}
hp_mouse= { "no : ":9001," brand name :":"HP MOUSE ","Mrp:":"450 rupees","discount : ":"50 rupees","new price :":400,"qn :":9}
dell_mouse= { "no : ":9002," brand name :":"DELL MOUSE","Mrp:":"600  rupees","discount : ":"50 rupees","new price :":550,"qn :":9}
zip_mouse= { "no : ":9003," brand name :":"ZIP MOUSE ","Mrp:":"760 rupees","discount : ":"50 rupees","new price :":760,"qn :":9}
i_mouse= { "no : ":9004," brand name :":"I MOUSE ","Mrp:":"430 rupees","discount : ":"30 rupees","new price :":400,"qn :":9}

total_items = {1:choco,2:nodeels,3:idlyrava,4:dosarava,5:chairs,6:studychair,7:decorators,8:diningtable,9:samsung_tv,10:mi_tv,11:realme_tv,12:samsung_moblie,13:mi_mobile,14:realme_mobile,15:dell_laptop,16:hp_laptop,17:mi_laptop,18:samsung_moblie,19:mi_mobile,20:realme_mobile,21:oppo_mobile,22:bosch_wm,23:samsung_wm,24:samsung_fg,25:bosch_fg,26:sunshine_home,27:moonlight_home,28:plesent_stars,29:hp_mouse,30:dell_mouse,31:zip_mouse,32:i_mouse}

print("hello  "+name+"  please choose what you want to buy")     # asking user what they want to buy
for i in again:                                                  # assigning values to different categories(cat)
  cat = int(input("to buy food items enter 1    to buy household items enter   2      to buy tv's enter 3   to buy laptops  enter 4   to buy mobiles enter :5     to buy  washingmachine enter:6    to buy fridge enter:7 to buy lamps enter : 8  to buy mouse enter:9"))
  if cat>=1 and cat<=9:
    if cat == 1:                                   # if category is 1 then showing user which are the items available in our shop in 1st category
      print(" food products available are  :")
      print(choco,idlyrava,dosarava,nodeels)
      choise = int(input("for choco : 1  for idlyrava : 2    for dosarava : 3    for noodeels : 4"))
      if choise == 1:                              # asking and checking for choise
        if choco["qn :"] != 0:
          kart.append(choco)                       # if choise ==1 and quantity is available appending choco to kart
          x.append(choco["new price :"])
          choco["qn :"] = choco["qn :"] - 1
        else:
          print("stock not available")            # if stock not avaialble 
      elif choise ==2:
        if idlyrava["qn :"] != 0:
          kart.append(idlyrava)
          x.append(idlyrava["new price :"])
          idlyrava["qn :"] = idlyrava["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 3:
        if dosarava["qn :"] != 0:
          kart.append(dosarava)
          x.append(dosarava["new price :"])
          dosarava["qn :"] = dosarava["qn :"] - 1
        else:
          print("stock not available")
      elif choise ==4:
        if nodeels["qn :"] != 0:
          kart.append(nodeels)
          x.append(nodeels["new price :"])
          nodeels["qn :"] = nodeels["qn :"] - 1
        else:
          print("stock not available")
      else:
        print("enter correct key")
    elif cat==2:
      print("households avaliable are  :")
      print(chairs,studychair,decorators,diningtable)
      choise = int(input("for chairs  : 1  for studychair  :2   for decorators  :3   for diningtable   :4"))
      if choise ==1:
        if chairs["qn :"] != 0:
          kart.append(chairs)
          x.append(chairs["new price :"])
          chairs["qn :"] = chairs["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 2:
        if studychair["qn :"] != 0:
          kart.append(studychair)
          x.append(studychair["new price :"])
          studychair["qn :"] = studychair["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 3:
        if decorators["qn :"] != 0:
          kart.append(decorators)
          x.append(decorators["new price :"])
          decorators["qn :"] = decorators["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 4:
        if diningtable["qn :"] != 0:
          kart.append(diningtable)
          x.append(diningtable["new price :"])
          diningtable["qn :"] = diningtable["qn :"] - 1
        else:
          print("stock not available")
      else :
        print("please enter correct no")
    elif cat==3:
      print("tv's  avaliable are  :")
      print(mi_tv,realme,samsung_tv)
      choise = int(input("for mi tv  : 1  for realme tv  :2   for samsung tv :3"))
      if choise ==1:
        if mi_tv["qn :"] != 0:
          kart.append(mi_tv)
          x.append(mi_tv["new price :"])
          mi_tv["qn :"] = mi_tv["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 2:
        if realme_tv["qn :"] != 0:
          kart.append(realme_tv)
          x.append(realme_tv["new price :"])
          realme_tv["qn :"] = realme_tv["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 3:
        if samsung_tv["qn :"] != 0:
          kart.append(samsung_tv)
          x.append(samsung_tv["new price :"])
          samsung_tv["qn :"] = samsung_tv["qn :"] - 1
        else:
          print("stock not available")
      else :
        print("please enter correct no")
    elif cat==4:
      print("laptops  avaliable are  :")
      print(dell_laptop,hp_laptop,mi_laptop)
      choise = int(input("for dell   : 1  for hp  :2   for mi  :3"))
      if choise ==1:
        if dell_laptop["qn :"] != 0:
          kart.append(dell_laptop)
          x.append(dell_laptop["new price :"])
          dell_laptop["qn :"] = dell_laptop["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 2:
        if hp_laptop["qn :"] != 0:
          kart.append(hp_laptop)
          x.append(hp_laptop["new price :"])
          hp_laptop["qn :"] = hp_laptop["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 3:
        if choco["qn :"] != 0:
          kart.append(mi_laptop)
          x.append(mi_laptop["new price :"])
          mi_laptop["qn :"] = mi_laptop["qn :"] - 1
        else:
          print("stock not available")
      else :
        print("please enter correct no")
    elif cat==5:
      print("mobiles avaliable are  :")
      print(samsung_moblie,mi_mobile,realme_mobile,oppo_mobile)
      choise = int(input("for samsung mobile  : 1  for mi mobiles  :2   for realme mobile  :3   for oppo mobiles   :4"))
      if choise ==1:
        if samsung_moblie["qn :"] != 0:
          kart.append(samsung_moblie)
          x.append(samsung_moblie["new price :"])
          samsung_moblie["qn :"] = samsung_moblie["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 2:
        if mi_mobile["qn :"] != 0:
          kart.append(mi_mobile)
          x.append(mi_mobile["new price :"])
          mi_mobile["qn :"] = mi_mobile["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 3:
        if realme_mobile["qn :"] != 0:
          kart.append(realme_mobile)
          x.append(realme_mobile["new price :"])
          realme_mobile["qn :"] = realme_mobile["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 4:
        if oppo_mobile["qn :"] != 0:
          kart.append(oppo_mobile)
          x.append(oppo_mobile["new price :"])
          oppo_mobile["qn :"] = oppo_mobile["qn :"] - 1
        else:
          print("stock not available")
      else :
        print("please enter correct no")
    elif cat==6:
      print("washing machines  avaliable are  :")
      print(bosch_wm,samsung_wm)
      choise = int(input("for bosch enter 1     samsung :2"))
      if choise ==1:
        if bosch_wm["qn :"] != 0:
          kart.append(bosch_wm)
          x.append(bosch_wm["new price :"])
          bosch_wm["qn :"] = bosch_wm["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 2:
        if samsung_wm["qn :"] != 0:
          kart.append(samsung_wm)
          x.append(samsung_wm["new price :"])
          samsung_wm["qn :"] = samsung_wm["qn :"] - 1
        else:
          print("stock not available")
      else :
        print("please enter correct no")
    elif cat==7:
      print("fridges  avaliable are  :")
      print(samsung_fg,bosch_fg)
      choise = int(input("for samsung :1   bosch :2"))
      if choise ==1:
        if samsung_fg["qn :"] != 0:
          kart.append(samsung_fg)
          x.append(samsung_fg["new price :"])
          samsung_fg["qn :"] = samsung_fg["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 2:
        if bosch_fg["qn :"] != 0:
          kart.append(bosch_fg)
          x.append(bosch_fg["new price :"])
          bosch_fg["qn :"] = bosch_fg["qn :"] - 1
        else:
          print("stock not available")
      else :
        print("please enter correct no")
    elif cat==8:
      print("lamps avaliable are  :")
      print(sunshine_home,moonlight_home,plesent_stars)
      choise = int(input("for sunshine :1   moonlight:2   plesent stars:3"))
      if choise ==1:
        if sunshine_home["qn :"] != 0:
          kart.append(sunshine_home)
          x.append(sunshine_home["new price :"])
          sunshine_home["qn :"] = sunshine_home["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 2:
        if moonlight_home["qn :"] != 0:
          kart.append(moonlight_home)
          x.append(moonlight_home["new price :"])
          moonlight_home["qn :"] = moonlight_home["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 3:
        if plesent_stars["qn :"] != 0:
          kart.append(plesent_stars)
          x.append(plesent_stars["new price :"])
          plesent_stars["qn :"] = plesent_stars["qn :"] - 1
        else:
          print("stock not available")
      else :
        print("please enter correct no")
    elif cat==9:
      print("laptop mouses  avaliable are  :")
      print(hp_mouse,dell_mouse,zip_mouse,i_mouse)
      choise = int(input("for hp mouse  : 1  for dell mouse  :2   for zip compony  :3   for i mouse   :4"))
      if choise ==1:
        if hp_mouse["qn :"] != 0:
          kart.append(hp_mouse)
          x.append(hp_mouse["new price :"])
          hp_mouse["qn :"] = hp_mouse["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 2:
        if dell_mouse["qn :"] != 0:
          kart.append(dell_mouse)
          x.append(dell_mouse["new price :"])
          dell_mouse["qn :"] = dell_mouse["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 3:
        if choco["qn :"] != 0:
          kart.append(zip_mouse)
          x.append(zip_mouse["new price :"])
          zip_mouse["qn :"] = zip_mouse["qn :"] - 1
        else:
          print("stock not available")
      elif choise == 4:
        if i_mouse["qn :"] != 0:
          kart.append(i_mouse)
          x.append(i_mouse["new price :"])
          i_mouse["qn :"] = i_mouse["qn :"] - 1
        else:
          print("stock not available")
      else :
        print("please enter correct no")
  else:
    print("enter correct key")
  if kart == []:                      #checking whether kart is full or not
    print(" your cart is empty because u have entered wrong key ")
  else:
    print("your kart is : ",kart)
    wait = int(input("can i bill your kart if yes enter 1 "))     # asking user to bill or do u have something to buy
    if wait == 1:
      print("Billing is under process :")
      coopuns = int(input("do you have any coopuns if yes enter 1  "))
      if coopuns == 1:
        bill = billing()
      else:
        mrp()                          #calling mrp function
    else:
      s = s+1
      again.append(s)
  continue
kartage = kart
new_kart = json.dumps(kartage)
fd.write(new_kart)
fd.close()
tot_items = json.dumps(total_items)
sd.write(tot_items)
sd.close()

# %%
2
